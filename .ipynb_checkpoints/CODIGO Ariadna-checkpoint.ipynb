# %%
#librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
import seaborn as sns
# %matplotlib inline

# %%
#importamos base de datos sociológicos 
data=pd.read_excel('anuario_2019.xlsx', sheet_name="2.3 Determinantes Sociológicos", usecols="A,B",header=None,index_col=0).dropna()
#importamos base de datos económicos
data2=pd.read_excel('anuario_2019.xlsx', sheet_name="Respecto del viaje", usecols="A,B",header=None,index_col=0).dropna()

# %%
print(data.iloc[8:16])
# Out:
#                   1
# 0
# NaN             AMG
# 15 a 25    0.107623
# 26 a 34    0.360987
# 35 a 44    0.186099
# 45 a 54    0.195067
# 55 a 64    0.112108
# 65 y más  0.0381166
# TOTAL             1

# %% [markdown]
# En la base de datos vienen las probabilidades de cada variable, por lo que no es necesario que las modifiquemos.

# %%
#segmentamos la base de datos para generar variables 
#nodo 1: EDAD
nac_edad=pd.DataFrame(data.iloc[9:15])
nac_edad.columns=(["AMG"])

int_edad=pd.DataFrame(data.iloc[17:23])
int_edad.columns=(["AMG"])

#nodo 2: ESTADO CIVIL
nac_civil=pd.DataFrame(data.iloc[25:30])
nac_civil.columns=(["AMG"])

int_civil=data.iloc[32:37]
int_civil.columns=(["AMG"])

#nodo 3: NIVEL DE ESCOLARIDAD
nac_school=data.iloc[39:45]
nac_school.columns=(["AMG"])
nac_school=pd.DataFrame(nac_school)

int_school=data.iloc[47:55]
int_school.columns=(["AMG"])
int_school=pd.DataFrame(int_school)

# nodo 4: MOTIVACIÓN PARA HACER EL VIAJE
nac_motiv=data2.iloc[13:20]
nac_motiv.columns=(["AMG"])
nac_motiv=pd.DataFrame(nac_motiv)

int_motiv=data2.iloc[22:30]
int_motiv.columns=(["AMG"])
int_motiv=pd.DataFrame(int_motiv)

# %%
print(int_edad,nac_edad)
# Out:
#                 AMG
# 0
# 15 a 25       0.125
# 26 a 34    0.471154
# 35 a 44    0.153846
# 45 a 54       0.125
# 55 a 64   0.0865385
# 65 y más  0.0384615                 AMG
# 0
# 15 a 25    0.107623
# 26 a 34    0.360987
# 35 a 44    0.186099
# 45 a 54    0.195067
# 55 a 64    0.112108
# 65 y más  0.0381166

# %%
int_edad.iloc[:,0]
# Out:
# 0
# 15 a 25         0.125
# 26 a 34      0.471154
# 35 a 44      0.153846
# 45 a 54         0.125
# 55 a 64     0.0865385
# 65 y más    0.0384615
# Name: AMG, dtype: object

# %%
n1 = pd.DataFrame(nac_edad)
int2 = pd.DataFrame(int_edad)
edad_gen = pd.merge(n1,int2,right_index=True, left_index=True)
edad_gen.corr(1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-203-d6408319912a> in <module>
#       2 int2 = pd.DataFrame(int_edad)
#       3 edad_gen = pd.merge(n1,int2,right_index=True, left_index=True)
# ----> 4 edad_gen.corr(1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in corr(self, method, min_periods)
#    7492                     correl[j, i] = c
#    7493         else:
# -> 7494             raise ValueError(
#    7495                 "method must be either 'pearson', "
#    7496                 "'spearman', 'kendall', or a callable, "
#
# ValueError: method must be either 'pearson', 'spearman', 'kendall', or a callable, '1' was supplied

# %%
def plot_histogram_discrete(distribucion:'distribución a graficar histograma',
                            xlabel:'x label',
                            ylabel: 'y label',
                            title: 'title'):
    '''Función para graficar el histograma de una distribución discreta'''
    plt.figure(figsize=[8,4])
    y,x = np.histogram(distribucion,bins = len(set(distribucion))) 
    plt.bar(list(set(distribucion)),y)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.show()

# %%
plt.bar(nac_civil.index,nac_civil.AMG, label='Histograma de probabilidades')
plt.xlabel('Estado Civil')
plt.ylabel('Probabilidad')
plt.title('Histograma de probabilides estado civil del TURISTA NACIONAL')
plt.legend()
plt.show()

# %%
plt.bar(nac_edad.index,nac_edad.AMG, label='Histograma de probabilidades')
plt.xlabel('Edad (años cumplidos)')
plt.ylabel('Probabilidad')
plt.title('Histograma de probabilides rango de edad del TURISTA NACIONAL')
plt.legend()
plt.show()

# %%
plt.bar(nac_school.index,nac_school.AMG, label='Histograma de probabilidades')
plt.xlabel('Nivel escolaridad')
plt.ylabel('Probabilidad')
plt.title('Histograma de probabilides nivel de escolaridad del TURISTA NACIONAL')
plt.legend()
plt.show()

# %%
plt.bar(nac_motiv.index,nac_motiv.AMG, label='Histograma de probabilidades')
plt.xlabel('Motivación del viaje')
plt.ylabel('Probabilidad')
plt.title('Histograma de probabilides motivación del TURISTA NACIONAL')
plt.legend()
plt.show()

# %% [markdown]
# ### 1.7 Visualización de resultados de simulación
#
# ### 1.8 Conclusiones

# %% [markdown]
# ### 1.9 Referencias.
# > https://secturjal.jalisco.gob.mx/invierte-en-jalisco/estadisticas
# > Citar (en formato APA) la bibliografía utilizada.
